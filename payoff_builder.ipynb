# %%
import numpy as np
import pandas as pd
import opstrat as op

# %%
op_1 = {'op_type':'c', 'strike':100, 'tr_type':'b', 'op_pr': 3.125}
op_2 = {'op_type':'p', 'strike':100, 'tr_type':'b', 'op_pr': 3.125}
op.multi_plotter(op_list=[op_1, op_2])

# %%
6.25/2
# Out:
# 3.125
