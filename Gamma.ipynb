# %%
import numpy as np
import pandas as pd
import datetime as dt
import yfinance as yf

# %% [markdown]
# # Preprocessing

# %%
raw_df = pd.read_csv('./Data/s&p500_option_data.csv', parse_dates=True)

raw_df['date'] = pd.to_datetime(raw_df['date'])
raw_df = raw_df.drop(['ticker', 'cusip', 'class', 'industry_group'], axis='columns')
raw_df.head()
# Out:
#     secid       date  days  delta  impl_volatility  impl_strike  impl_premium  \
# 0  108105 2000-01-03    10    -90              NaN          0.0           0.0
# 1  108105 2000-01-03    10    -85              NaN          0.0           0.0
# 2  108105 2000-01-03    10    -80              NaN          0.0           0.0
# 3  108105 2000-01-03    10    -75              NaN          0.0           0.0
# 4  108105 2000-01-03    10    -70              NaN          0.0           0.0
#
#    dispersion cp_flag   sic  index_flag  exchange_d issue_type
# 0         NaN       P  9999           1       32768          A
# 1         NaN       P  9999           1       32768          A
# 2         NaN       P  9999           1       32768          A
# 3         NaN       P  9999           1       32768          A
# 4         NaN       P  9999           1       32768          A

# %%
raw_df[raw_df.date == '2000-01-03'].dropna()
# Out:
#       secid       date  days  delta  impl_volatility  impl_strike  \
# 34   108105 2000-01-03    30    -90         0.223466     1590.011
# 35   108105 2000-01-03    30    -85         0.215552     1561.223
# 36   108105 2000-01-03    30    -80         0.209840     1540.204
# 37   108105 2000-01-03    30    -75         0.207249     1523.929
# 38   108105 2000-01-03    30    -70         0.207566     1510.458
# ..      ...        ...   ...    ...              ...          ...
# 369  108105 2000-01-03   730     70         0.233149     1438.914
# 370  108105 2000-01-03   730     75         0.242101     1360.038
# 371  108105 2000-01-03   730     80         0.250719     1271.917
# 372  108105 2000-01-03   730     85         0.258227     1171.522
# 373  108105 2000-01-03   730     90         0.264596     1050.263
#
#      impl_premium  dispersion cp_flag   sic  index_flag  exchange_d issue_type
# 34      132.30780    0.037185       P  9999           1       32768          A
# ...

# %%
spot = yf.download('^GSPC')['2000-01-02':]
spot.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2000-01-03  1469.250000  1478.000000  1438.359985  1455.219971  1455.219971
# 2000-01-04  1455.219971  1455.219971  1397.430054  1399.420044  1399.420044
# 2000-01-05  1399.420044  1413.270020  1377.680054  1402.109985  1402.109985
# 2000-01-06  1402.109985  1411.900024  1392.099976  1403.449951  1403.449951
# 2000-01-07  1403.449951  1441.469971  1400.729980  1441.469971  1441.469971
#
#                 Volume
# Date
# 2000-01-03   931800000
# 2000-01-04  1009000000
# 2000-01-05  1085500000
# 2000-01-06  1092300000
# 2000-01-07  1225200000

# %%
# Out:
#           secid       date  days  delta  impl_volatility  impl_strike  \
# 0        108105 2000-01-03    10    -90              NaN        0.000
# 1        108105 2000-01-03    10    -85              NaN        0.000
# 2        108105 2000-01-03    10    -80              NaN        0.000
# 3        108105 2000-01-03    10    -75              NaN        0.000
# 4        108105 2000-01-03    10    -70              NaN        0.000
# ...         ...        ...   ...    ...              ...          ...
# 2070459  108105 2021-12-31   730     70         0.250166     4117.904
# 2070460  108105 2021-12-31   730     75         0.265997     3860.017
# 2070461  108105 2021-12-31   730     80         0.283967     3558.327
# 2070462  108105 2021-12-31   730     85         0.303781     3196.287
# 2070463  108105 2021-12-31   730     90         0.325091     2739.703
#
#          impl_premium  dispersion cp_flag     cusip   sic  index_flag  \
# ...
